# %%
import numpy as np

# %%
pip install pycryptodome
# Out:
# Collecting pycryptodome
#   Downloading pycryptodome-3.11.0-cp35-abi3-win_amd64.whl (1.8 MB)
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from Crypto.PublicKey import RSA
import json
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import requests
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\fatih\AppData\Roaming\nltk_data...
# True

# %%
sid = SIA()

# %%
url_ny_dnews = 'https://www.nydailynews.com/arcio/rss/category/news/?sort=display_date:desc'
url_cbs_bost = 'https://boston.cbslocal.com/feed/'
url_times = 'https://rss.nytimes.com/services/xml/rss/nyt/HomePage.xml'

# %%
news_arr = []
news_outlet = []

for url in [url_ny_dnews, url_cbs_bost, url_times]:
    result = requests.get(url)
    soup = BeautifulSoup(result.content, features='xml')
    items = soup.findAll('item')
    if url == url_times:
         news_outlet = 'newyork_times'
    elif url == 'url_ny_dnews':
         news_outlet = 'ny_dailynews'
    elif url == 'url_cbs_bost':
         news_outlet = 'cbs_boston'
 
    news_items = []
    for item in items:
         news_item= {}
         news_item['News_Outlet'] = news_outlet
         news_item['title'] = item.title.text
         news_item['description'] = item.description.text
         news_item['link'] = item.link.text
         news_item['pubDate'] = item.pubDate.text
         news_items.append(news_item)
    news_arr.append(news_items)
    
for item in news_arr:
     print(len(item))
# Out:
# 77
# 40
# 57

# %%
df_newyork_times = pd.DataFrame(news_arr[0], columns=['News_Outlet', 'title', 'description', 'link', 'pubDate'])
df_ny_dailynews = pd.DataFrame(news_arr[1], columns=['News_Outlet', 'title', 'description', 'link', 'pubDate'])
df_cbs_boston = pd.DataFrame(news_arr[2], columns=['News_Outlet', 'title', 'description', 'link', 'pubDate'])
df_scrapped = pd.concat([df_newyork_times, df_ny_dailynews, df_cbs_boston], ignore_index=True)
df_scrapped.head(10)
# Out:
#   News_Outlet                                              title  \
# 0          []  Wife gets life sentence for helping husband pl...
# 1          []  Man accused of killing brother-in-law over COV...
# 2          []  Descendant of famed Native American leader Sit...
# 3          []  Stiffest charge sticks for ex-officer who shot...
# 4          []  NAACP urges athletes not to play for Texas teams
# 5          []  Philadelphia pays Walter Wallace Jr.’s family ...
# 6          []  Florida sues Biden over contractor vaccine man...
# 7          []  Former NY Gov. Cuomo facing criminal sex charg...
# 8          []   Oklahoma death row prisoner John Grant executed
# 9          []  Family of 8-year-old girl killed by police nea...
#
#                                          description  \
# 0  Rhonda Carlson, 48, took a plea deal to avoid ...
# 1  Jeffrey Burnham, 46, was captured by police Oc...
# 2  Sitting Bull was best known for his unificatio...
# 3  Former Minneapolis police officer Kim Potter l...
# 4  The NAACP wants to mess with Texas, where spor...
# 5  Part of the settlement required Philadelphia t...
# 6  DeSantis has vowed legal action over federal v...
# 7  The summons, filed by the Albany County Sherif...
# 8  The U.S. Supreme Court on Thursday lifted the ...
# 9  Three Sharon Hill police officers killed Fanta...
#
#                                                 link  \
# 0  https://www.nydailynews.com/news/national/ny-a...
# 1  https://www.nydailynews.com/news/national/ny-m...
# 2  https://www.nydailynews.com/news/national/ny-d...
# 3  https://www.nydailynews.com/news/crime/ny-kim-...
# 4  https://www.nydailynews.com/news/national/ny-n...
# 5  https://www.nydailynews.com/news/national/ny-w...
# 6  https://www.nydailynews.com/news/politics/us-e...
# 7  https://www.nydailynews.com/news/politics/new-...
# 8  https://www.nydailynews.com/news/crime/ny-supr...
# 9  https://www.nydailynews.com/news/national/ny-f...
#
#                            pubDate
# 0  Fri, 29 Oct 2021 02:17:26 +0000
# 1  Fri, 29 Oct 2021 01:24:54 +0000
# 2  Fri, 29 Oct 2021 00:36:11 +0000
# 3  Fri, 29 Oct 2021 00:28:29 +0000
# 4  Fri, 29 Oct 2021 00:15:43 +0000
# 5  Fri, 29 Oct 2021 00:13:16 +0000
# 6  Fri, 29 Oct 2021 00:09:27 +0000
# 7  Thu, 28 Oct 2021 22:57:26 +0000
# 8  Thu, 28 Oct 2021 22:52:31 +0000
# 9  Thu, 28 Oct 2021 22:35:25 +0000

# %%
import datetime

scores = df_scrapped ['title'].apply(sid.polarity_scores).tolist()
scores_df = pd.DataFrame(scores)
df_scrapped = df_scrapped.join(scores_df, rsuffix='_right')
df_scrapped.head(10)
# Out:
#   News_Outlet                                              title  \
# 0          []  Wife gets life sentence for helping husband pl...
# 1          []  Man accused of killing brother-in-law over COV...
# 2          []  Descendant of famed Native American leader Sit...
# 3          []  Stiffest charge sticks for ex-officer who shot...
# 4          []  NAACP urges athletes not to play for Texas teams
# 5          []  Philadelphia pays Walter Wallace Jr.’s family ...
# 6          []  Florida sues Biden over contractor vaccine man...
# 7          []  Former NY Gov. Cuomo facing criminal sex charg...
# 8          []   Oklahoma death row prisoner John Grant executed
# 9          []  Family of 8-year-old girl killed by police nea...
#
#                                          description  \
# 0  Rhonda Carlson, 48, took a plea deal to avoid ...
# 1  Jeffrey Burnham, 46, was captured by police Oc...
# 2  Sitting Bull was best known for his unificatio...
# 3  Former Minneapolis police officer Kim Potter l...
# 4  The NAACP wants to mess with Texas, where spor...
# 5  Part of the settlement required Philadelphia t...
# 6  DeSantis has vowed legal action over federal v...
# 7  The summons, filed by the Albany County Sherif...
# 8  The U.S. Supreme Court on Thursday lifted the ...
# 9  Three Sharon Hill police officers killed Fanta...
#
#                                                 link  \
# 0  https://www.nydailynews.com/news/national/ny-a...
# 1  https://www.nydailynews.com/news/national/ny-m...
# 2  https://www.nydailynews.com/news/national/ny-d...
# 3  https://www.nydailynews.com/news/crime/ny-kim-...
# 4  https://www.nydailynews.com/news/national/ny-n...
# 5  https://www.nydailynews.com/news/national/ny-w...
# 6  https://www.nydailynews.com/news/politics/us-e...
# 7  https://www.nydailynews.com/news/politics/new-...
# 8  https://www.nydailynews.com/news/crime/ny-supr...
# 9  https://www.nydailynews.com/news/national/ny-f...
#
#                            pubDate    neg    neu    pos  compound
# 0  Fri, 29 Oct 2021 02:17:26 +0000  0.186  0.651  0.163   -0.3612
# 1  Fri, 29 Oct 2021 01:24:54 +0000  0.431  0.447  0.122   -0.8225
# 2  Fri, 29 Oct 2021 00:36:11 +0000  0.000  1.000  0.000    0.0000
# 3  Fri, 29 Oct 2021 00:28:29 +0000  0.000  1.000  0.000    0.0000
# 4  Fri, 29 Oct 2021 00:15:43 +0000  0.203  0.797  0.000   -0.2584
# 5  Fri, 29 Oct 2021 00:13:16 +0000  0.000  1.000  0.000    0.0000
# 6  Fri, 29 Oct 2021 00:09:27 +0000  0.000  1.000  0.000    0.0000
# 7  Thu, 28 Oct 2021 22:57:26 +0000  0.355  0.645  0.000   -0.6705
# 8  Thu, 28 Oct 2021 22:52:31 +0000  0.532  0.288  0.180   -0.7096
# 9  Thu, 28 Oct 2021 22:35:25 +0000  0.390  0.610  0.000   -0.7506
